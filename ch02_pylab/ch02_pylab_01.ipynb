# %%
import sys
print(sys.version)
# Out:
# 3.4.9 (default, Aug 14 2018, 21:28:57)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-28)]

# %%
import pylab

# %%
ax=[0., 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
ay=[0.0, 0.25, 1.0, 2.25, 4.0, 6.25, 9.0]
pylab.plot(ax, ay)
pylab.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
a1 = fig.add_subplot(111)
x = np.linspace(-2, 2, 1000)
line_cosh, = a1.plot(x, np.cosh(x))
line_quad, = a1.plot(x, x**2/2)
plt.show()

# %% [markdown]
# This is a test **markdown**.
#
# # title1
# ## title 2
#
# 1. item 1
# 1. item 2
#     1. subitem 1
#     1. subitem 2
#
# $$f(x)$$
#
# $f(x)$

# %%
import random

# %%
ax, ay = [], []
for i in range(100):
    ax.append(random.random())
    ay.append(random.random())
pylab.scatter(ax,ay)
pylab.show()

# %%
import math
import pylab
xmin, xmax = -2. * math.pi, 2. * math.pi
n = 50
x = [0.] * n
y = [0.] * n
dx = (xmax - xmin)/(n-1)
for i in range(n):
    xpt=xmin + i*dx
    x[i]=xpt
    y[i]=math.sin(xpt)**2
    
pylab.plot(x,y)
pylab.show()

# %%
n =50
x = pylab.linspace(xmin, xmax, n)
y1=pylab.sin(x)**2
y2=pylab.cos(x)**2
pylab.plot(x,y1)
pylab.plot(x,y2)
pylab.show()

# %%
n=100
xmin=-20
xmax=20
x=pylab.linspace(xmin,xmax,n)
y=pylab.sin(x)/x
pylab.plot(x,y)
pylab.show()

# %% [markdown]
# ## axis labels

# %%
t= pylab.linspace(0., 0.1, 1000)
Vp_uk, Vp_us = 230, 110
f_uk, f_us = 50, 60
V_uk = Vp_uk * pylab.sin(2 * pylab.pi * f_uk * t)
V_us = Vp_us * pylab.sin(2 * pylab.pi * f_us * t)
pylab.plot(t*1000, V_uk, label = 'UK')
pylab.plot(t*1000, V_us, label = 'US')
pylab.title('A comparison of AC voltages in the UK and US')
pylab.xlabel('Time/ms', fontsize=16.)
pylab.ylabel('Voltage/V', fontsize=16.)
pylab.legend()
pylab.show()

# %% [markdown]
# ## Using LaTeX in `pylab`

# %%
import pylab
pylab.rc('text',usetex=True)#enable latex
x=pylab.linspace(-10,10,1001)
for n in range(1,5):
    y = x**n * pylab.sin(x)
    y /= max(y)
    pylab.plot(x,y,label=r'$x^{}\sin x$'.format(n))
pylab.legend(loc='lower center')
pylab.show()
pylab.savefig('sinnx.pdf',format='pdf')# save to pdf file
pylab.savefig('sinnx.svg',format='svg',transparent=True)# save to svg file

# %%
from pyculib import rand
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-28a2c4a0ff83> in <module>()
# ----> 1 from pyculib import rand
#
# ModuleNotFoundError: No module named 'pyculib'
