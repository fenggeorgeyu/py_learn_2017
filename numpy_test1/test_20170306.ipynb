# %%
import pandas as pd
df1 = pd.read_csv('data/obtree2_creation_summary.csv',sep='\t')
df1
# Out:
#    dataset  obtree_c
# 0       10   0.73086
# 1       64   4.10246
# 2     1024  47.07870

# %%
data_obc_vs_clean = pd.read_csv('data/obtree2_creation_vs_data_cleaning.csv')
data_obc_vs_clean
# Out:
#    dataset         time            group
# 0       10    14.440333    data_cleaning
# 1       64   104.695833    data_cleaning
# 2     1024  2023.230333    data_cleaning
# 3       10     0.730860  obtree_creation
# 4       64     4.102460  obtree_creation
# 5     1024    47.078700  obtree_creation

# %% [markdown]
# Here is a good tutorial of `pandas`:
# http://pandas.pydata.org/pandas-docs/stable/10min.html
#
# `metaplotlib` tutorial:
# http://matplotlib.org/users/pyplot_tutorial.html
#
# Here is `ggplot` for python:
# * http://ggplot.yhathq.com/
# * http://ggplot.yhathq.com/docs/index.html

# %%
from ggplot import *
# ggplot(data_obc_vs_clean, aes(x='dataset',y='time',group='group'))+ \
#     geom_line(aes(color='group'))+ \
#     geom_point(aes(shape='group', color='group'),size=2.5)+ \
#     theme_bw()+ \
#     labs(x="dataset (MB)",y="time (s)")
    
ggplot(data_obc_vs_clean, aes(x='dataset', y='time', shape='group', color='group')) + \
    theme_bw()+\
    geom_line()+\
    geom_point(size=60)
# Out:
# <ggplot: (288558512)>
